# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/100_days_ML_cX_ISI_DS/blob/main/handling_missing_cat_values_day_37.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/train (2).csv", usecols = ['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual      81
# SalePrice        0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].isnull().sum()
# Out:
# np.int64(81)

# %%
from sklearn.impute import SimpleImputer
si = SimpleImputer(strategy = 'most_frequent')
df['GarageQual'] = pd.DataFrame(si.fit_transform(df[['GarageQual']]),columns = ['GarageQual'])

# %%
df.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual       0
# SalePrice        0
# dtype: int64

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna("missing")

# %%
df['FireplaceQu'].value_counts()
# Out:
# FireplaceQu
# missing    690
# Gd         380
# TA         313
# Fa          33
# Ex          24
# Po          20
# Name: count, dtype: int64

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0     missing         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000
