# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/100_days_ML_cX_ISI_DS/blob/main/knn_imputer_day_39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/content/train.csv" ,usecols = ['Age','Pclass','Fare','Survived'])

# %%
df.head()
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250
# 3         1       1  35.0  53.1000
# 4         0       3  35.0   8.0500

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# Fare          0
# dtype: int64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
knn = KNNImputer(n_neighbors=1)
X_train_imputed = knn.fit_transform(X_train)
X_test_imputed = knn.transform(X_test)

# %%
lr = LogisticRegression()
lr.fit(X_train_imputed,y_train)
y_pred = lr.predict(X_test_imputed)
accuracy_score(y_test,y_pred)
# Out:
# 0.7206703910614525

# %%
# comparison with the SimpleImputer Mean
si = SimpleImputer()
X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
lr2 = LogisticRegression()
lr2.fit(X_train_trf2,y_train)
y_pred2 = lr2.predict(X_test_trf2)
accuracy_score(y_test,y_pred2)
# Out:
# 0.6927374301675978

# %%
accuracy_L = []
i_L = []
for i in range(1,10):
    knn = KNNImputer(n_neighbors = i,weights = 'distance')
    X_train_imputed = knn.fit_transform(X_train)
    X_test_imputed = knn.transform(X_test)
    lr = LogisticRegression()
    lr.fit(X_train_imputed,y_train)
    y_pred = lr.predict(X_test_imputed)
    a = accuracy_score(y_test,y_pred)
    accuracy_L.append(a)
    i_L.append(i)
    d = dict(zip(i_L,accuracy_L))

    if d[i] == max((accuracy_L)):
      print(i)

print(max(accuracy_L))
print(d)
# Out:
# 1
# 0.7206703910614525
# {1: 0.7206703910614525, 2: 0.7094972067039106, 3: 0.7039106145251397, 4: 0.7039106145251397, 5: 0.7039106145251397, 6: 0.7039106145251397, 7: 0.7039106145251397, 8: 0.7039106145251397, 9: 0.7039106145251397}
