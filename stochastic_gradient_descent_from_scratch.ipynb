# %% [markdown]
# <a href="https://colab.research.google.com/github/UKD1211/100_days_ML_cX_ISI_DS/blob/main/stochastic_gradient_descent_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes

import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
print(X.shape)
print(y.shape)
# Out:
# (442, 10)
# (442,)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()
start = time.time()
reg.fit(X_train,y_train)
print(time.time() - start)
# Out:
# 0.0025167465209960938

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class SGDregressor:

  def __init__(self,learning_rate = 0.01,epochs = 100):
    self.coef_ = None
    self.intercept_ = None
    self.lr = learning_rate
    self.epochs = epochs

  def fit(self,X_train,y_train):
    self.intercept_ = 0
    self.coef_ = np.ones(X_train.shape[1])
    for i in range(self.epochs):
      for j in range(X_train.shape[0]):
        indx = np.random.randint(0,X_train.shape[0])
        y_hat = np.dot(X_train[indx],self.coef_) + self.intercept_
        self.intercept_ = self.intercept_ - (self.lr * -2 * (y_train[indx] - y_hat))
        self.coef_ = self.coef_ - (self.lr * -2 * np.dot((y_train[indx] - y_hat),X_train[indx]))
    print(self.coef_)
    print(self.intercept_)

  def predict(self,X_test):
    return np.dot(X_test, self.coef_) + self.intercept_

# %%
X_train.shape[0]
# Out:
# 353

# %%
X_train[0]
# Out:
# array([-0.00188202, -0.04464164, -0.06979687, -0.01255612, -0.00019301,
#        -0.00914259,  0.07072993, -0.03949338, -0.06291688,  0.04034337])

# %%
y_train[0]
# Out:
# np.float64(48.0)

# %%
np.random.randint(0,X_train.shape[0])
# Out:
# 261

# %%
X_train[:,0].shape
# Out:
# (353,)

# %%
sgd = SGDregressor(learning_rate=0.05,epochs=100)

# %%
start = time.time()
sgd.fit(X_train,y_train)
print(time.time() - start)
# Out:
# [ -15.22925627 -201.17774272  533.45348793  341.60094409  -91.46944121
#  -109.74854201 -172.48120659   63.85527497  552.90350448   72.00213573]
# 130.06804893543546
# 0.3831357955932617

# %%
y_pred = sgd.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.345146569825346
